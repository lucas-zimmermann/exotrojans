# %%
import matplotlib.pyplot as plt
from batman_simulation import simulate_trojan_swarm

# Run the simulation with default parameters
phase_deg, flux, ax = simulate_trojan_swarm(
    N_swarm=200,
    sigma_deg=8.0,
    seed=1
)

plt.show()

# %%
import matplotlib.pyplot as plt
from stacked_lightcurves import plot_stacked_tess_lightcurves

ax = plot_stacked_tess_lightcurves(
    csv_path="nexsci.csv",
    num=10,
    bins=1000,
)

plt.show()
